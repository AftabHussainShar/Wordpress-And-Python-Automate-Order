# %%
pip install woocommerce
# Out:
# Requirement already satisfied: woocommerce in c:\users\aftab hussain\appdata\local\programs\python\python312\lib\site-packages (3.0.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\aftab hussain\appdata\local\programs\python\python312\lib\site-packages (from woocommerce) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aftab hussain\appdata\local\programs\python\python312\lib\site-packages (from requests->woocommerce) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aftab hussain\appdata\local\programs\python\python312\lib\site-packages (from requests->woocommerce) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aftab hussain\appdata\local\programs\python\python312\lib\site-packages (from requests->woocommerce) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aftab hussain\appdata\local\programs\python\python312\lib\site-packages (from requests->woocommerce) (2024.2.2)

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('orders', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break


print(all_orders)
# Convert orders data to JSON
# orders_json = json.dumps(all_orders)

# # Save JSON data to a file
# with open('orders.json', 'w') as json_file:
#     json_file.write(orders_json)

# print("JSON data saved to 'orders.json' file.")
# Out:
# c:\Users\Aftab Hussain\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ['code', 'message', 'data']

# %%
from woocommerce import API
import json

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Read order details from JSON file
with open('order.json') as f:
    order_data = json.load(f)

# Post the order
new_order = wcdata.post("orders", order_data)

print("New order created:")
print(new_order)
# Out:
# New order created:
# <Response [500]>

# %%
from woocommerce import API
import json

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Define customer data
customer_data = {
    "email": "aftab@mail.com",
    "first_name": "aftab",
    "last_name": "Hussain",
    "username": "aftab.hussain",
    "billing": {
        "first_name": "Aftab",
        "last_name": "Hussain",
        "address_1": "969 Market",
        "city": "San Francisco",
        "state": "CA",
        "postcode": "94103",
        "country": "US",
        "email": "aftab@mail.com",
        "phone": "03133473749"
    },
    "shipping": {
        "first_name": "Aftab",
        "last_name": "Hussain",
        "address_1": "969 Market",
        "city": "San Francisco",
        "state": "CA",
        "postcode": "94103",
        "country": "US",
    }
}

# Post the customer data
new_customer = wcdata.post("customers", customer_data)

print("New customer created:")
print(new_customer)
# Out:
# New customer created:
# <Response [400]>

# %%
import requests

url = 'https://mikeelford.com/wp-json/wc/v3/orders'
consumer_key = 'ck_159cf0c676f2012cda4777ed31a58da9b3b54aab'
consumer_secret = 'cs_54effa9e46e3c83dbf53bb04637f1f7a130995df'

response = requests.get(url, auth=(consumer_key, consumer_secret))

if response.status_code == 200:
    orders = response.json()
    print("Orders retrieved successfully:")
    for order in orders:
        print("Order ID:", order['id'])
        # Print other order details as needed
else:
    print("Failed to retrieve orders. Status code:", response.status_code)
# Out:
# Failed to retrieve orders. Status code: 401

# %%
from woocommerce import API

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Delete all products from WooCommerce
page = 1
while True:
    try:
        # Retrieve products from the current page
        products_response = wcdata.get('products', params={'page': page})
        products = products_response.json()
        
        print(products_response)

        # Delete each product from the current page
        for product in products:
            product_id = product['id']
            wcdata.delete(f'products/{product_id}', params={'force': True})

        # Check if there are more pages of products
        if 'next' in products_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error deleting products:", e)
        break

print("All products deleted from WooCommerce.")
# Out:
# <Response [401]>
# Error deleting products: string indices must be integers, not 'str'
# All products deleted from WooCommerce.

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('products', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break

print(all_orders)
# Convert orders data to JSON
# orders_json = json.dumps(all_orders)

# # Save JSON data to a file
# with open('orders.json', 'w') as json_file:
#     json_file.write(orders_json)

# print("JSON data saved to 'orders.json' file.")
# Out:
# [{'id': 3599, 'name': 'DraftPics Portrait Composite Image DIGITAL DOWNLOAD', 'slug': 'draftpics-portrait-composite-image-digital-download', 'permalink': 'https://mikeelford.com/product/draftpics-portrait-composite-image-digital-download/', 'date_created': '2024-02-24T22:43:39', 'date_created_gmt': '2024-02-25T03:43:39', 'date_modified': '2024-02-24T22:45:17', 'date_modified_gmt': '2024-02-25T03:45:17', 'type': 'simple', 'status': 'publish', 'featured': False, 'catalog_visibility': 'hidden', 'description': "<p>In today's modern world, a lot of people want the digital version of our DraftPics Composite Image. This image is sent to you via a downloadable link. Of course, we welcome you to show and share our composite image as we hope you love the image we've created for your favorite athlete. Sizes vary during the creation process, so we don't recommend printing these. Of course, if you desire prints, we would hope you will consider the rest of the options within our shop.</p>\n", 'short_description': '<p>In today&#8217;s modern world, a lot of people want the digital version of our DraftPics Composite Image. This image is sent to you via a downloadable link. Of course, we welcome you to show and share our composite image as we hope you love the image we&#8217;ve created for your favorite athlete. Sizes vary during the creation process, so we don&#8217;t recommend printing these. Of course, if you desire prints, we would hope you will consider the rest of the options within our shop.</p>\n', 'sku': 'DIG100002', 'price': '35', 'regular_price': '35', 'sale_price': '', 'date_on_sale_from': None, 'date_on_sale_from_gmt': None, 'date_on_sale_to': None, 'date_on_sale_to_gmt': None, 'on_sale': False, 'purchasable': True, 'total_sales': 0, 'virtual': True, 'downloadable': False, 'downloads': [], 'download_limit': 0, 'download_expiry': 0, 'external_url': '', 'button_text': '', 'tax_status': 'taxable', 'tax_class': '', 'manage_stock': False, 'stock_quantity': None, 'backorders': 'no', 'backorders_allowed': False, 'backordered': False, 'low_stock_amount': None, 'sold_individually': True, 'weight': '', 'dimensions': {'length': '', 'width': '', 'height': ''}, 'shipping_required': False, 'shipping_taxable': False, 'shipping_class': '', 'shipping_class_id': 0, 'reviews_allowed': False, 'average_rating': '0.00', 'rating_count': 0, 'upsell_ids': [], 'cross_sell_ids': [], 'parent_id': 0, 'purchase_note': '', 'categories': [{'id': 94, 'name': 'Team PhotoDay', 'slug': 'team-photoday'}], 'tags': [{'id': 95, 'name': 'Team PhotoDay Digital', 'slug': 'team-photoday-digital'}], 'images': [{'id': 3657, 'date_created': '2024-02-24T22:45:12', 'date_created_gmt': '2024-02-25T03:45:12', 'date_modified': '2024-02-24T22:45:12', 'date_modified_gmt': '2024-02-25T03:45:12', 'src': 'https://mikeelford.com/wp-content/uploads/2024/02/Gracin-Talbot-II.jpg', 'name': 'Gracin-Talbot-II.jpg', 'alt': ''}], 'attributes': [], 'default_attributes': [], 'variations': [], 'grouped_products': [], 'menu_order': 27, 'price_html': '<span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">&#36;</span>35.00</bdi></span>', 'related_ids': [], 'meta_data': [{'id': 9732, 'key': 'mtheme__menu_choice', 'value': ''}, {'id': 9733, 'key': 'mtheme__page_title', 'value': ''}, {'id': 9734, 'key': 'mtheme__page_fullscreentoggle', 'value': ''}, {'id': 9735, 'key': 'mtheme__pagebackground_opacity', 'value': ''}, {'id': 9736, 'key': 'mtheme__meta_background_choice', 'value': ''}, {'id': 9737, 'key': 'mtheme__slideshow_bgfullscreenpost', 'value': ''}, {'id': 9738, 'key': 'mtheme__video_bgfullscreenpost', 'value': ''}, {'id': 9739, 'key': 'mtheme__meta_background_url', 'value': ''}, {'id': 9740, 'key': '_square_item_id', 'value': 'LOXFDJSKLH5FHBL3B5MMP4CN'}, {'id': 9741, 'key': '_square_item_version', 'value': '1691824692850'}, {'id': 9742, 'key': '_square_item_image_id', 'value': '3TWD5SEQZXIOZO6BOJUESDB3'}, {'id': 9743, 'key': '_square_uploaded_image_id', 'va ...

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('orders', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break


print(all_orders)
# Convert orders data to JSON
# orders_json = json.dumps(all_orders)

# # Save JSON data to a file
# with open('orders.json', 'w') as json_file:
#     json_file.write(orders_json)

# print("JSON data saved to 'orders.json' file.")
# Out:
# [{'id': 36995, 'parent_id': 0, 'status': 'processing', 'currency': 'CAD', 'version': '8.8.3', 'prices_include_tax': False, 'date_created': '2024-05-21T11:33:35', 'date_modified': '2024-05-21T11:33:38', 'discount_total': '0.00', 'discount_tax': '0.00', 'shipping_total': '0.00', 'shipping_tax': '0.00', 'cart_tax': '0.00', 'total': '25.00', 'total_tax': '0.00', 'customer_id': 0, 'order_key': 'wc_order_mY8oFiyXGSn81', 'billing': {'first_name': 'JAXSON', 'last_name': 'BOOTH', 'company': '', 'address_1': '', 'address_2': '', 'city': '', 'state': '', 'postcode': '', 'country': 'CA', 'email': 'ZOE.B.BOOTH@GMAIL.COM', 'phone': ''}, 'shipping': {'first_name': '', 'last_name': '', 'company': '', 'address_1': '', 'address_2': '', 'city': '', 'state': '', 'postcode': '', 'country': '', 'phone': ''}, 'payment_method': 'square_credit_card', 'payment_method_title': 'Credit Card', 'transaction_id': 'x44UcC2k9IhghjkSFCtXMzYsqpNZY', 'customer_ip_address': '2001:56b:9ff3:bf8e:e8cb:322c:dc52:93b2', 'customer_user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 17_4_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.4.1 Mobile/15E148 Safari/604.1', 'created_via': 'checkout', 'customer_note': '', 'date_completed': None, 'date_paid': '2024-05-21T11:33:38', 'cart_hash': '401513a088f9e79e640466e322a2367f', 'number': '36995', 'meta_data': [{'id': 99921, 'key': '_billing__billing_colour_jersey', 'value': 'Orange and green'}, {'id': 99922, 'key': '_billing__billing_player_number', 'value': '6'}, {'id': 99920, 'key': '_billing__billing_team_name_or_sponsor', 'value': 'Erie shores family dental'}, {'id': 99919, 'key': '_billing_billing_division', 'value': 'U11'}, {'id': 99923, 'key': '_billing_parent_information', 'value': ''}, {'id': 99924, 'key': '_billing_parent_name', 'value': 'ZOE BOOTH'}, {'id': 99925, 'key': '_billing_parents_phone_number', 'value': '5195519561'}, {'id': 99918, 'key': '_billing_select_one', 'value': 'Kingsville Soccer Association'}, {'id': 99927, 'key': '_mrm_newsletter_subscription', 'value': 'No'}, {'id': 99931, 'key': '_order_number', 'value': '23356'}, {'id': 99928, 'key': '_showcase_privacy_policy', 'value': 'Yes'}, {'id': 99938, 'key': '_wc_square_credit_card_account_four', 'value': '3410'}, {'id': 99939, 'key': '_wc_square_credit_card_authorization_amount', 'value': '25.00'}, {'id': 99940, 'key': '_wc_square_credit_card_authorization_code', 'value': 'x44UcC2k9IhghjkSFCtXMzYsqpNZY'}, {'id': 99942, 'key': '_wc_square_credit_card_card_expiry_date', 'value': '2029-7'}, {'id': 99943, 'key': '_wc_square_credit_card_card_type', 'value': 'mastercard'}, {'id': 99941, 'key': '_wc_square_credit_card_charge_captured', 'value': 'yes'}, {'id': 99937, 'key': '_wc_square_credit_card_customer_id', 'value': 'NB50BJ3WJFWFPVRQ9YKJ8N2SDC'}, {'id': 99934, 'key': '_wc_square_credit_card_is_tender_type_card', 'value': '1'}, {'id': 99933, 'key': '_wc_square_credit_card_retry_count', 'value': '0'}, {'id': 99944, 'key': '_wc_square_credit_card_square_location_id', 'value': 'DZPRNH2D3STX8'}, {'id': 99945, 'key': '_wc_square_credit_card_square_order_id', 'value': 'b4IkiCgPtNKg433SAkAtzXtAmUQZY'}, {'id': 99946, 'key': '_wc_square_credit_card_square_version', 'value': '4.6.1'}, {'id': 99936, 'key': '_wc_square_credit_card_trans_date', 'value': '2024-05-21 11:33:38'}, {'id': 99935, 'key': '_wc_square_credit_card_trans_id', 'value': 'x44UcC2k9IhghjkSFCtXMzYsqpNZY'}, {'id': 99949, 'key': '_wcpdf_invoice_creation_trigger', 'value': 'email_attachment'}, {'id': 99950, 'key': '_wcpdf_invoice_date', 'value': '1716309218'}, {'id': 99951, 'key': '_wcpdf_invoice_date_formatted', 'value': '2024-05-21 11:33:38'}, {'id': 99948, 'key': '_wcpdf_invoice_display_date', 'value': 'invoice_date'}, {'id': 99952, 'key': '_wcpdf_invoice_number', 'value': '222'}, {'id': 99953, 'key': '_wcpdf_invoice_number_data', 'value': {'number': 222, 'formatted_number': '222', 'prefix': '', 'suffix': '', 'document_type': 'invoice', 'order_id': 36995, 'padding': ''}}, {'id': 99947, ...

# %%
from woocommerce import API

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Delete all orders from WooCommerce
page = 1
while True:
    try:
        # Retrieve orders from the current page
        orders_response = wcdata.get('orders', params={'page': page})
        orders = orders_response.json()

        # Delete each order from the current page
        for order in orders:
            order_id = order['id']
            wcdata.delete(f'orders/{order_id}', params={'force': True})

        # Check if there are more pages of orders
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error deleting orders:", e)
        break

print("All orders deleted from WooCommerce.")
# Out:
# All orders deleted from WooCommerce.

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('products/attributes', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break


# print(all_orders)
# Convert orders data to JSON
orders_json = json.dumps(all_orders)

# Save JSON data to a file
with open('products_attributes.json', 'w') as json_file:
    json_file.write(orders_json)

print("JSON data saved to 'orders.json' file.")
# Out:
# JSON data saved to 'orders.json' file.

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Retrieve all categories from WooCommerce API
all_categories = []

page = 1
while True:
    try:
        categories_response = wcdata.get('products/attributes', params={'page': page})
        categories = categories_response.json()
        all_categories.extend(categories)
        if 'next' in categories_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching categories:", e)
        break

# Delete all categories
for category in all_categories:
    try:
        wcdata.delete(f"products/categories/{category['id']}", params={'force': True})  # Assuming you want to force delete
        print(f"Deleted category: {category['name']}")
    except Exception as e:
        print(f"Error deleting category {category['name']}: {e}")

print("All categories deleted.")
# Out:
# Deleted category: Uncategorized
# All categories deleted.

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('"products/reviews', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break


# print(all_orders)
# Convert orders data to JSON
orders_json = json.dumps(all_orders)

# Save JSON data to a file
with open('reviews.json', 'w') as json_file:
    json_file.write(orders_json)

print("JSON data saved to 'orders.json' file.")
# Out:
# JSON data saved to 'orders.json' file.

# %%
from woocommerce import API

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Retrieve all reviews from WooCommerce API
all_reviews = []

page = 1
while True:
    try:
        reviews_response = wcdata.get('products/reviews', params={'page': page})
        reviews = reviews_response.json()
        all_reviews.extend(reviews)
        if 'next' in reviews_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching reviews:", e)
        break

# Delete all reviews
for review in all_reviews:
    try:
        wcdata.delete(f"products/reviews/{review['id']}")
        print(f"Deleted review: {review['id']}")
    except Exception as e:
        print(f"Error deleting review {review['id']}: {e}")

print("All reviews deleted.")
# Out:
# All reviews deleted.

# %%
import json
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('customers', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break

# Convert orders data to JSON
orders_json = json.dumps(all_orders)

# Save JSON data to a file
with open('customers.json', 'w') as json_file:
    json_file.write(orders_json)

print("JSON data saved to 'orders.json' file.")
# Out:
# JSON data saved to 'orders.json' file.

# %%
from woocommerce import API
import openpyxl

# Initialize WooCommerce API
wcdata = API(
    url='https://mikeelford.com/',
    consumer_key='ck_159cf0c676f2012cda4777ed31a58da9b3b54aab',
    consumer_secret='cs_54effa9e46e3c83dbf53bb04637f1f7a130995df',
    version='wc/v3'
)

# Load existing Excel file
wb = openpyxl.load_workbook('Draftpics.xlsx')

# Retrieve or create the specific sheet
if 'From Woocommerce' in wb.sheetnames:
    ws = wb['From Woocommerce']
else:
    ws = wb.create_sheet(title='From Woocommerce')

# Clear existing data from the sheet, if any
ws.delete_rows(2, ws.max_row)

# Retrieve all orders from WooCommerce API
all_orders = []

page = 1
while True:
    try:
        orders_response = wcdata.get('products', params={'page': page})
        orders = orders_response.json()
        all_orders.extend(orders)
        if 'next' in orders_response.headers.get('Link', ''):
            page += 1
        else:
            break
    except Exception as e:
        print("Error fetching orders:", e)
        break
    
print(all_orders)

# # Extract relevant fields from WooCommerce API response
# for idx, order in enumerate(all_orders, start=2):  # Start from row 2, assuming headers are in row 1
#     ws[f'A{idx}'] = order['id']
#     ws[f'B{idx}'] = order['date_created']
#     if order['status'] == 'custom-status':
#         ws[f'C{idx}'] = 'created'
#     else:
#         ws[f'C{idx}'] = order['status']
#     # Add dollar formatting to the "Total" field
#     cell = ws[f'E{idx}']
#     # cell.number_format = '$#,##0.00'
#     # Assign the value to the cell
#     cell.value = order['total']
#     ws[f'E{idx}'] = next((meta['value'] for meta in order['meta_data'] if meta['key'] == '_billing_select_one'), None)
#     ws[f'F{idx}'] = order['billing']['last_name'] + ' ' + order['billing']['first_name']

# # Save the modified Excel file
# wb.save('Draftpics.xlsx')
# Out:
# [{'id': 36608, 'name': 'GameDay Billboard', 'slug': 'gameday-billboard', 'permalink': 'https://mikeelford.com/product/gameday-billboard/', 'date_created': '2024-05-05T11:34:48', 'date_created_gmt': '2024-05-05T16:34:48', 'date_modified': '2024-05-05T11:40:25', 'date_modified_gmt': '2024-05-05T16:40:25', 'type': 'simple', 'status': 'publish', 'featured': False, 'catalog_visibility': 'visible', 'description': '<p>Get your very own GameDay Billboard graphic, complete with your favourite players details. There is no better way to hype up a KSA Game Day!</p>\n', 'short_description': '', 'sku': 'Dig-1000255', 'price': '20.00', 'regular_price': '20.00', 'sale_price': '', 'date_on_sale_from': None, 'date_on_sale_from_gmt': None, 'date_on_sale_to': None, 'date_on_sale_to_gmt': None, 'on_sale': False, 'purchasable': True, 'total_sales': 1, 'virtual': False, 'downloadable': False, 'downloads': [], 'download_limit': -1, 'download_expiry': -1, 'external_url': '', 'button_text': '', 'tax_status': 'taxable', 'tax_class': '', 'manage_stock': False, 'stock_quantity': None, 'backorders': 'no', 'backorders_allowed': False, 'backordered': False, 'low_stock_amount': None, 'sold_individually': False, 'weight': '', 'dimensions': {'length': '', 'width': '', 'height': ''}, 'shipping_required': True, 'shipping_taxable': True, 'shipping_class': '', 'shipping_class_id': 0, 'reviews_allowed': False, 'average_rating': '0.00', 'rating_count': 0, 'upsell_ids': [], 'cross_sell_ids': [], 'parent_id': 0, 'purchase_note': '', 'categories': [{'id': 51, 'name': 'Digitals', 'slug': 'digitals'}], 'tags': [], 'images': [{'id': 36609, 'date_created': '2024-05-05T06:34:35', 'date_created_gmt': '2024-05-05T16:34:35', 'date_modified': '2024-05-05T06:34:35', 'date_modified_gmt': '2024-05-05T16:34:35', 'src': 'https://mikeelford.com/wp-content/uploads/2024/05/KSA-Billboard-Digital.jpg', 'name': 'KSA-Billboard-Digital', 'alt': ''}], 'attributes': [], 'default_attributes': [], 'variations': [], 'grouped_products': [], 'menu_order': 0, 'price_html': '<span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">&#36;</span>20.00</bdi></span>', 'related_ids': [3549, 3578, 3660, 3659], 'meta_data': [{'id': 2463993, 'key': '_last_editor_used_jetpack', 'value': 'classic-editor'}, {'id': 2464001, 'key': '_wp_page_template', 'value': 'default'}, {'id': 2464019, 'key': '_booked_appointment', 'value': 'no'}, {'id': 2464020, 'key': 'product_video_url', 'value': ''}, {'id': 2464021, 'key': '_product_video_url', 'value': 'field_175353125234'}, {'id': 2464022, 'key': '_yoast_wpseo_primary_product_cat', 'value': ''}, {'id': 2464023, 'key': '_yoast_wpseo_content_score', 'value': '90'}, {'id': 2464024, 'key': '_yoast_wpseo_estimated-reading-time-minutes', 'value': '1'}, {'id': 2464025, 'key': '_yoast_wpseo_wordproof_timestamp', 'value': ''}, {'id': 2464075, 'key': '_square_item_id', 'value': 'CA3AVH7RVADATUAT6XXQCJHI'}, {'id': 2464076, 'key': '_square_item_image_id', 'value': 'SPFW25YTYDP5EJBFWQJGEEZN'}, {'id': 2464077, 'key': '_square_item_variation_id', 'value': '4QCVCTDTXWKM4XK24MEIGDBS'}, {'id': 2464078, 'key': '_square_item_version', 'value': '1714927225350'}, {'id': 2464079, 'key': '_square_item_variation_version', 'value': '1714927225350'}, {'id': 2464080, 'key': '_square_uploaded_image_id', 'value': '36609'}], 'stock_status': 'instock', 'has_options': False, 'post_password': '', 'yoast_head': '<!-- This site is optimized with the Yoast SEO plugin v22.6 - https://yoast.com/wordpress/plugins/seo/ -->\n<title>GameDay Billboard - Mike Elford Photography</title>\n<!-- Admin only notice: this page does not show a meta description because it does not have one, either write it for this page specifically or go into the [Yoast SEO - Settings] menu and set up a template. -->\n<meta name="robots" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n<link rel="canonical" href="https://mikeelford.com/product/gameday-billboa ...
